# %%
import findspark, random
findspark.init("/u/cs451/packages/spark")

from pyspark import SparkContext, SparkConf
sc = SparkContext(appName="YourTest", master="local[2]", conf=SparkConf().set('spark.ui.port', random.randrange(4000,5000)))

# %%
from simple_tokenize import simple_tokenize
from spamminess import spamminess
from math import exp
from operator import add
import numpy as np
n=5
m=1000

# %%
dataset='bank_final.txt'

# %%
n=1

# %%
sents = sc.textFile(dataset).map(lambda x: (x[:-3],x[-1:]))\
.map(lambda x: (x[0],1 if x[1]=="+" else -1 if x[1]=='-' else 0))

# %%
def generate_ngrams(sent):
    ngrams_list = []
    words_list = simple_tokenize(sent[0])
    for num in range(0, len(words_list)-N+1):
        ngram = ' '.join(words_list[num:num + N])
        ngrams_list.append(ngram)
 
    return (ngrams_list,sent[1])

# %%
def helper(imp,i2):
    out = []
    lst = imp
    for string in lst:
        ele = ((string, i2), 1)
        out.append(ele)
    return out

# %%
def helper2 (inp1, inp2):
    return (inp1[0]+inp2[0],inp1[1]+inp2[1])

# %%
def helper3 (inp):
    p1=(inp[1])[0]+0.0
    n1=(inp[1])[1]+0.0
    p2 = Positives - p1
    n2 = Negatives - n1
    w1 = (p1+n1)/(Positives+Negatives)
    w2 = 1 - w1
    prob1 = p1/(p1+n1)
    prob2 = 0
    if p2!=0:
        prob2 = p2/(p2+n2)
    neg_entropy_1 = prob1*np.log10(prob1)/np.log10(2.0) + (1-prob1)*np.log10(1-prob1)/np.log10(2.0)
    neg_entropy_2 = prob1*np.log10(prob2)/np.log10(2.0) + (1-prob2)*np.log10(1-prob2)/np.log10(2.0)
    IG = w1 * neg_entropy_1 + w2 * neg_entropy_2
    if np.isnan(IG):
        IG = float('-inf')
    return (inp[0], IG)

# %%
def extractNGram(sents,m):
    Positives = sents.filter(lambda x: x[1]>0).count()
    Negatives = sents.filter(lambda x: x[1]<0).count()
    interm = sents.filter(lambda x: x[1]!=0).map(generate_ngrams)\
    .flatMap(lambda x: helper(np.unique(x[0]),x[1])).reduceByKey(add)\
    .map(lambda x: ((x[0])[0], (x[1], 0)) if (x[0])[1] >0 else ((x[0])[0], (0, x[1])))\
    .reduceByKey(helper2).map(helper3).top(m, key=lambda x: x[1])
    output= sc.parallelize(interm).map(lambda x: x[0]).zipWithIndex().collectAsMap()
    return output

# %%
def accuracy(f_classified, w):
    corrects = f_classified.map(lambda x: ('',1 if spamminess(x[0],w)*x[1]>0 else 0))\
    .reduceByKey(add).take(1)
    return (corrects[0])[1]/f_classified.count()

# %%
extractNGram(sents,100)
# Out:
# {'alongside a body of wate': 0,
#  'bank generally refers to the': 1,
#  'geography the word bank generally': 2,
#  'land alongside a body of': 3,
#  'word bank generally refers to': 4,
#  'bed of a river creek': 5,
#  'of a river creek or': 6,
#  'or river bank is the': 7,
#  'river bank is the terrain': 8,
#  'terrain alongside the bed of': 9,
#  'the bed of a river': 10,
#  'the terrain alongside the bed': 11,
#  'bank consists of the sides': 12,
#  'between which the flow is': 13,
#  'channel between which the flow': 14,
#  'consists of the sides of': 15,
#  'the bank consists of the': 16,
#  'the channel between which the': 17,
#  'the sides of the channel': 18,
#  'a well known example of': 19,
#  'an observer looking downstream a': 20,
#  'and right bank refer to': 21,
#  'bank and right bank refer': 22,
#  'being the sections of paris': 23,
#  'descriptive terms left bank and': 24,
#  'example of this being the': 25,
#  'left bank and right bank': 26,
#  'observer looking downstream a well': 27,
#  'of paris as defined by': 28,
#  'of this being the sections': 29,
#  'perspective of an observer looking': 30,
#  'refer to the perspective of': 31,
#  'sections of paris as defined': 32,
#  'terms left bank and right': 33,
#  'this being the sections of': 34,
#  'to the perspective of an': 35,
#  'a river bank is the': 36,
#  'along the edge of a': 37,
#  'land along the edge of': 38,
#  'the edge of a rive': 39,
#  'the land along the edge': 40,
#  'forward to the river bank': 41,
#  'hand to hold me bac': 42,
#  'i ran forward to the': 43,
#  'i think had put out': 44,
#  'river bank though someone colonel': 45,
#  'the river bank though someone': 46,
#  'though someone colonel weston i': 47,
#  'to the river bank though': 48,
#  'and where there were houses': 49,
#  'at least there would be': 50,
#  'be houses scattered along the': 51,
#  'houses there were dry clothes': 52,
#  'least there would be houses': 53,
#  'the river bank and where': 54,
#  'there were houses there were': 55,
#  'there would be houses scattered': 56,
#  'down the phaeton on the': 57,
#  'insisted that the water tanks': 58,
#  'intense irritation put down the': 59,
#  'phaeton on the river ban': 60,
#  'tanks needed filling and to': 61,
#  'the water tanks needed filling': 62,
#  'to my intense irritation put': 63,
#  'water tanks needed filling and': 64,
#  'is on the left bank': 65,
#  'left bank of the rive': 66,
#  'on the left bank of': 67,
#  'the left bank of the': 68,
#  'the university is on the': 69,
#  'the river flowed over the': 70,
#  'tall luxuriant plants grew along': 71,
#  'they were nestled between rocks': 72,
#  'river bank and the stamp': 73,
#  'as canoes can launch from': 74,
#  'can launch from the river': 75,
#  'canoes can launch from the': 76,
#  'launch from the river ban': 77,
#  'such as canoes can launch': 78,
#  'watercraft such as canoes can': 79,
#  'at the river bank for': 80,
#  'now trickling at the river': 81,
#  'people are now trickling at': 82,
#  'the river bank for the': 83,
#  'trickling at the river bank': 84,
#  'and power company of a': 85,
#  'bank of the battenkill south': 86,
#  'company of a plant on': 87,
#  'of a plant on the': 88,
#  'on the west bank of': 89,
#  'south of union street bridge': 90,
#  'the battenkill south of union': 91,
#  'the manchester light and power': 92,
#  'the next step was construction': 93,
#  'the west bank of the': 94,
#  'was construction by the manchester': 95,
#  'west bank of the battenkill': 96,
#  'a man stood calling to': 97,
#  'bank a man stood calling': 98,
#  'bank the west bank a': 99}

# %%
maps = extractNGram(sents,m)
def tonums(interm):
    numlst = []
    strlst = interm[0]
    
    for ele in strlst:
        val = maps.get(ele)
        numlst.append(val)
    return (numlst, interm[1])

# %%
toNGram = sents.filter(lambda x: x[1]!=0).map(generate_ngrams).map(tonums)

# %%
def trainer(tngrm, n_itr, alpha, delta):
    w={}
    for itr in range(0,n_itr):
        d_w = toNGram.map(lambda x: (x[0], 1 if x[1]>0 else 0))\
            .map(lambda x: (x[0],x[1],1/(1+exp(-spamminess(x[0],w)))))\
            .map(lambda x: (x[0],(x[1]-x[2])*alpha))\
            .flatMap(lambda x: map(lambda y: (y,x[1]), x[0]))\
            .reduceByKey(add)
        w = d_w.map(lambda x: (x[0],x[1]+w.get(x[0],0))).collectAsMap()
        s_d_w =  d_w.map(lambda x: ("",abs(x[1]))).reduceByKey(add).take(1)
        if (s_d_w[0])[1] < delta:
            break
    return w

# %%
# Out:
# [([502, 184, 507, 503, 505, 185, 508, 183, 504, 506, 509], 1),
#  ([514,
#    193,
#    189,
#    194,
#    186,
#    190,
#    510,
#    191,
#    187,
#    513,
#    511,
#    195,
#    515,
#    196,
#    192,
#    188,
#    512],
#   1),
#  ([205,
#    200,
#    519,
#    204,
#    517,
#    197,
#    516,
#    199,
#    203,
#    202,
#    198,
#    520,
#    521,
#    201,
#    522,
#    518],
#   1),
#  ([529,
#    209,
#    213,
#    215,
#    530,
#    206,
#    527,
#    525,
#    531,
#    212,
#    523,
#    207,
#    208,
#    210,
#    526,
#    211,
#    528,
#    214,
#    524],
#   1),
#  ([534,
#    532,
#    219,
#    544,
#    217,
#    220,
#    538,
#    222,
#    542,
#    539,
#    216,
#    541,
#    224,
#    543,
#    536,
#    225,
#    221,
#    223,
#    226,
#    545,
#    533,
#    218,
#    537,
#    535,
#    540],
#   1),
#  ([228, 552, 549, 551, 553, 547, 546, 548, 227, 231, 230, 550, 229], 1),
#  ([562,
#    243,
#    232,
#    234,
#    556,
#    561,
#    557,
#    240,
#    235,
#    233,
#    555,
#    558,
#    237,
#    554,
#    236,
#    244,
#    239,
#    241,
#    560,
#    242,
#    559,
#    238],
#   1),
#  ([563, 246, 247, 249, 566, 250, 245, 567, 565, 248, 568, 251, 564, 252], 1),
#  ([581,
#    570,
#    262,
#    574,
#    264,
#    572,
#    254,
#    265,
#    577,
#    579,
#    257,
#    259,
#    261,
#    573,
#    571,
#    253,
#    580,
#    263,
#    578,
#    575,
#    569,
#    265,
#    576,
#    260,
#    256,
#    258,
#    255],
#   1),
#  ([585,
#    274,
#    266,
#    591,
#    279,
#    595,
#    589,
#    592,
#    281,
#    272,
#    280,
#    271,
#    268,
#    588,
#    282,
#    596,
#    594,
#    584,
#    278,
#    269,
#    597,
#    276,
#    583,
#    277,
#    273,
#    586,
#    593,
#    267,
#    275,
#    590,
#    587,
#    582,
#    270],
#   1),
#  ([604,
#    285,
#    289,
#    287,
#    293,
#    295,
#    283,
#    292,
#    290,
#    284,
#    296,
#    603,
#    288,
#    294,
#    605,
#    601,
#    286,
#    600,
#    602,
#    291,
#    598,
#    599],
#   1),
#  ([298, 607, 608, 609, 297, 606], 1),
#  ([307,
#    301,
#    616,
#    303,
#    299,
#    612,
#    305,
#    309,
#    306,
#    300,
#    614,
#    310,
#    308,
#    610,
#    611,
#    615,
#    613,
#    302,
#    304],
#   1),
#  ([319,
#    618,
#    315,
#    320,
#    620,
#    623,
#    314,
#    622,
#    318,
#    312,
#    624,
#    311,
#    316,
#    619,
#    621,
#    617,
#    313,
#    625,
#    626,
#    317],
#   1),
#  ([632,
#    640,
#    324,
#    631,
#    328,
#    325,
#    627,
#    636,
#    323,
#    322,
#    639,
#    332,
#    638,
#    641,
#    630,
#    633,
#    634,
#    642,
#    628,
#    643,
#    329,
#    331,
#    637,
#    330,
#    635,
#    326,
#    321,
#    629,
#    327],
#   1),
#  ([343,
#    651,
#    342,
#    652,
#    644,
#    653,
#    333,
#    345,
#    645,
#    340,
#    336,
#    338,
#    335,
#    337,
#    344,
#    650,
#    339,
#    648,
#    649,
#    647,
#    334,
#    341,
#    646],
#   1),
#  ([347, 654, 656, 658, 659, 346, 655, 348, 657], 1),
#  ([663, 349, 660, 661, 351, 354, 662, 352, 350, 353], 1),
#  ([665, 355, 356, 664], 1),
#  ([828, 2, 831, 4, 1, 827, 829, 832, 830, 3, 0], -1),
#  ([834, 839, 837, 7, 8, 836, 838, 11, 9, 835, 10, 5, 6, 833], -1),
#  ([16, 12, 15, 841, 18, 842, 840, 17, 14, 13, 843], -1),
#  ([853,
#    24,
#    33,
#    26,
#    22,
#    21,
#    852,
#    845,
#    31,
#    35,
#    854,
#    30,
#    850,
#    20,
#    27,
#    849,
#    847,
#    19,
#    856,
#    848,
#    25,
#    29,
#    34,
#    23,
#    855,
#    32,
#    28,
#    851,
#    844,
#    846],
#   -1),
#  ([36, 859, 857, 858, 40, 38, 37, 39], -1),
#  ([43,
#    866,
#    41,
#    48,
#    46,
#    45,
#    861,
#    47,
#    867,
#    862,
#    869,
#    44,
#    868,
#    863,
#    865,
#    864,
#    860,
#    42],
#   -1),
#  ([50,
#    53,
#    56,
#    879,
#    51,
#    872,
#    874,
#    870,
#    54,
#    873,
#    871,
#    49,
#    878,
#    55,
#    877,
#    52,
#    875,
#    876],
#   -1),
#  ([888,
#    58,
#    886,
#    62,
#    64,
#    61,
#    884,
#    881,
#    880,
#    63,
#    883,
#    59,
#    882,
#    885,
#    57,
#    887,
#    60],
#   -1),
#  ([69, 889, 65, 67, 68, 66], -1),
#  ([70, 890], -1),
#  ([71, 892, 893, 891], -1),
#  ([72, 899, 895, 894, 897, 896, 898], -1),
#  ([905, 903, 900, 904, 73, 902, 901], -1),
#  ([906, 79, 78, 74, 76, 75, 77], -1),
#  ([82, 907, 81, 84, 80, 83, 908], -1),
#  ([668,
#    363,
#    357,
#    678,
#    672,
#    674,
#    368,
#    676,
#    667,
#    666,
#    365,
#    367,
#    364,
#    671,
#    371,
#    362,
#    675,
#    670,
#    680,
#    669,
#    359,
#    369,
#    679,
#    677,
#    360,
#    673,
#    372,
#    361,
#    358,
#    370,
#    366],
#   1),
#  ([377,
#    378,
#    373,
#    682,
#    376,
#    688,
#    375,
#    684,
#    683,
#    685,
#    379,
#    374,
#    380,
#    687,
#    681,
#    686],
#   1),
#  ([93,
#    915,
#    919,
#    95,
#    912,
#    911,
#    92,
#    914,
#    913,
#    85,
#    918,
#    87,
#    88,
#    909,
#    917,
#    89,
#    94,
#    96,
#    86,
#    916,
#    91,
#    910,
#    90],
#   -1),
#  ([389,
#    394,
#    694,
#    381,
#    387,
#    392,
#    691,
#    695,
#    393,
#    692,
#    383,
#    384,
#    388,
#    386,
#    690,
#    696,
#    689,
#    395,
#    391,
#    382,
#    390,
#    693,
#    385,
#    697,
#    396],
#   1),
#  ([416,
#    702,
#    418,
#    405,
#    717,
#    710,
#    411,
#    718,
#    410,
#    703,
#    400,
#    414,
#    715,
#    408,
#    417,
#    705,
#    407,
#    701,
#    700,
#    719,
#    712,
#    402,
#    711,
#    714,
#    403,
#    415,
#    716,
#    709,
#    397,
#    720,
#    713,
#    721,
#    399,
#    708,
#    707,
#    698,
#    706,
#    401,
#    404,
#    419,
#    723,
#    412,
#    420,
#    722,
#    704,
#    406,
#    699,
#    413,
#    409,
#    421,
#    398],
#   1),
#  ([921, 920, 101, 99, 102, 922, 98, 97, 100], -1),
#  ([113,
#    115,
#    927,
#    114,
#    943,
#    923,
#    931,
#    105,
#    936,
#    120,
#    109,
#    933,
#    941,
#    108,
#    126,
#    118,
#    924,
#    116,
#    117,
#    111,
#    104,
#    932,
#    944,
#    940,
#    937,
#    930,
#    934,
#    103,
#    107,
#    925,
#    110,
#    935,
#    119,
#    125,
#    929,
#    121,
#    926,
#    928,
#    112,
#    939,
#    106,
#    938,
#    123,
#    942,
#    124,
#    122],
#   -1),
#  ([129,
#    964,
#    134,
#    138,
#    947,
#    946,
#    955,
#    960,
#    148,
#    133,
#    131,
#    948,
#    140,
#    146,
#    957,
#    141,
#    954,
#    958,
#    136,
#    132,
#    952,
#    145,
#    137,
#    963,
#    961,
#    966,
#    144,
#    135,
#    143,
#    953,
#    959,
#    139,
#    950,
#    956,
#    962,
#    965,
#    127,
#    147,
#    945,
#    130,
#    128,
#    951,
#    142,
#    949],
#   -1),
#  ([968, 150, 970, 149, 969, 967, 971], -1),
#  ([972, 153, 154, 151, 976, 152, 975, 974, 973], -1),
#  ([986,
#    158,
#    982,
#    980,
#    159,
#    156,
#    985,
#    157,
#    978,
#    977,
#    979,
#    155,
#    984,
#    981,
#    160,
#    983,
#    161],
#   -1),
#  ([163, 162, 165, 164, 987, 988], -1),
#  ([169, 167, 990, 992, 170, 991, 989, 993, 168, 166], -1),
#  ([997, 173, 172, 171, 995, 999, 996, 994, None, 998], -1),
#  ([None], -1),
#  ([None,
#    None,
#    None,
#    None,
#    182,
#    971,
#    None,
#    178,
#    180,
#    174,
#    None,
#    None,
#    181,
#    177,
#    176,
#    179,
#    None,
#    175],
#   -1),
#  ([731,
#    729,
#    423,
#    733,
#    422,
#    726,
#    724,
#    732,
#    735,
#    728,
#    725,
#    424,
#    734,
#    426,
#    730,
#    727,
#    425,
#    736],
#   1),
#  ([743, 746, 739, 744, 427, 430, 431, 741, 740, 742, 737, 738, 429, 428, 745],
#   1),
#  ([434, 752, 750, 753, 754, 747, 751, 755, 748, 432, 749, 433, 756], 1),
#  ([777,
#    763,
#    770,
#    772,
#    762,
#    765,
#    442,
#    767,
#    446,
#    448,
#    438,
#    445,
#    764,
#    769,
#    757,
#    759,
#    774,
#    771,
#    436,
#    444,
#    447,
#    437,
#    775,
#    439,
#    773,
#    768,
#    758,
#    443,
#    761,
#    440,
#    441,
#    776,
#    760,
#    435,
#    766],
#   1),
#  ([455,
#    463,
#    780,
#    454,
#    451,
#    783,
#    784,
#    452,
#    457,
#    458,
#    462,
#    453,
#    786,
#    779,
#    461,
#    459,
#    450,
#    449,
#    460,
#    785,
#    782,
#    781,
#    456,
#    778],
#   1),
#  ([819,
#    805,
#    821,
#    787,
#    818,
#    822,
#    799,
#    792,
#    812,
#    468,
#    476,
#    481,
#    802,
#    485,
#    804,
#    810,
#    482,
#    789,
#    814,
#    807,
#    484,
#    491,
#    791,
#    483,
#    790,
#    472,
#    492,
#    474,
#    816,
#    796,
#    801,
#    797,
#    467,
#    788,
#    486,
#    495,
#    477,
#    817,
#    497,
#    490,
#    806,
#    493,
#    793,
#    488,
#    498,
#    800,
#    466,
#    473,
#    813,
#    470,
#    465,
#    494,
#    475,
#    478,
#    820,
#    815,
#    471,
#    809,
#    480,
#    479,
#    489,
#    794,
#    469,
#    464,
#    811,
#    795,
#    823,
#    496,
#    803,
#    808,
#    798,
#    487],
#   1),
#  ([825, 824, 826, 499, 501, 500], 1)]

# %%
w=trainer(toNGram, 20,0.1,0.1)

# %%
def accuracy(f_classified, w):
    corrects = f_classified.map(lambda x: ('',1 if spamminess(x[0],w)*x[1]>0 else 0))\
    .reduceByKey(add).take(1)
    return (corrects[0])[1]/f_classified.count()

# %%
corrects=toNGram.map(lambda x: ('',1 if spamminess(x[0],w)*x[1]>0 else 0)).reduceByKey(add).take(1)

# %%
(corrects[0])[1]/toNGram.count()
# Out:
# 1.0

# %%
def run (sents0, sents_test, model_path, result_path, save, N, m, niter, threshold, alpha, delta):
    n_unclassified = 0
    n_unclassified_new = sents0.filter(lambda x: x[1]== 0).count()
    itr = 0
    sents = sents0
    f_map = {}
    w = {}
    def generate_ngrams(sent):
        ngrams_list = []
        words_list = simple_tokenize(sent[0])
        for num in range(0, len(words_list)-N+1):
            ngram = ' '.join(words_list[num:num + N])
            ngrams_list.append(ngram)
            return (ngrams_list,sent[1])
    while(n_unclassified_new>0 and n_unclassified_new != n_unclassified):
        f_map = extractNGram(sents,m)
        def tonums(interm):
            numlst = []
            strlst = interm[0]
            for ele in strlst:
                val = f_map.get(ele)
                numlst.append(val)
            return (numlst, interm[1])
        f_classified = sents.filter(lambda x: x[1]!=0).map(generate_ngrams).map(tonums)
        w = trainer(f_classified, niter, alpha, delta) 
        train_acc =  accuracy(f_classified, w)
        f_unclassified = sents.filter(lambda x: x[1]==0).map(generate_ngrams).map(tonums)
        def findscore (inp):
            label = inp[1]
            if inp[1]==0:
                score = spamminess(inp[0],w)
                label = score
            if score > threshold:
                label = 1
            elif score < -threshold:
                label = -1
            return (inp[0], label)
        sents_new = f_unclassified.map(findscore)
        
        n_unclassified = sents.filter(lambda x: x[1] == 0).count()
        n_unclassified_new = sents_new.filter(lambda x: x[1]== 0).count()
        
        itr = itr+1
        sents = sents_new
    f_test = sents_test.map(generate_ngrams).map(tonums)
    test_acc =  accuracy(f_test, w)
    #if save:
    #    sents.map(lambda x: (x[0]+'+' if x[1]==1 else x[0]+'-' if x[1]==-1 else 0))\
    #    .saveAsTextFile(result_path)
    #    model = f_map.map(lambda x: (x[0], w.get(x[1],0.0))).saveAsTextFile(model_path)
    return test_acc

# %%
run (sents_train, sents_test, model_path, result_path, 1, 4, 500, 10, 0.6, 0.4, 0.3)
# Out:
# 0.5

# %%
sents_indexed = sents.zipWithIndex()
sents_train = sents_indexed.filter(lambda x: (x[0])[1] == 0 or x[1]%5!=0).map(lambda x: x[0])
sents_test = sents_indexed.filter(lambda x: (x[0])[1] != 0 and x[1]%5==0).map(lambda x: x[0])
model_path='model/group_x_model'
result_path='result/group_x_result'

# %%
extractNGram(sents_test, 3)
# Out:
# {'bed of a river creek': 0,
#  'of a river creek or': 1,
#  'or river bank is the': 2}

# %%
result_path='result/group_x_result'

# %%
  def test(model_path:String, sent:String, sc:SparkContext){
    val str_w = sc.textFile(model_path+"/part-00000")
    .map(s =>{
      val words = s.slice(1,s.size-1).split(",")
      (words(0), words(1).toDouble)
    })
    val f_w = str_w.zipWithIndex

    val w = f_w.map(t=>(t._2.toInt,t._1._2)).collectAsMap()
    val f_map = f_w.map(t=>(t._1._1,t._2.toInt)).collectAsMap()

    val N = str_w.take(1)(0)._1.split(" ").size

    println("using "+N+"-Gram")
    val score = classify(toNGramSingle(sent,f_map,N),w)
    println("score is: "+score)
    if(score>0){
      println("classified as +")
    }
    else{
      println("classified as -")
    }

  }

# %%
def test(model_path, sent):
    str_w = sc.textFile(model_path+"/part-00000")

# %%
m=4
w={}
alpha =0.1

# %%
d_w = toNGram.map(lambda x: (x[0], 1 if x[1]>0 else 0))\
.map(lambda x: (x[0],x[1],1/(1+exp(-spamminess(x[0],w)))))\
.map(lambda x: (x[0],(x[1]-x[2])*alpha))\
.flatMap(lambda x: map(lambda y: (y,x[1]), x[0]))\
.reduceByKey(add)

s_d_w =  d_w.map(lambda x: ("",abs(x[1]))).reduceByKey(add).take(1)
# Out:
# [([None, None, None, None, None, None, None, None, None, None, None], 1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None, None, None, None, None, None], 1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None, None, None, None, None, None, None, None, None], 1),
#  ([None, None, None, None, None, None, None, None, None, None], 1),
#  ([None, None, None, None], 1),
#  ([None, 2, None, None, 1, None, None, None, None, 3, 0], -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None, None, None, None, None, None, None, None, None, None, None], -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None, None, None, None, None, None, None, None], -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None, None, None, None, None, None], -1),
#  ([None, None], -1),
#  ([None, None, None, None], -1),
#  ([None, None, None, None, None, None, None], -1),
#  ([None, None, None, None, None, None, None], -1),
#  ([None, None, None, None, None, None, None], -1),
#  ([None, None, None, None, None, None, None], -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None, None, None, None, None, None, None, None, None], -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None, None, None, None, None, None, None], -1),
#  ([None, None, None, None, None, None, None, None, None], -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None, None, None, None, None, None], -1),
#  ([None, None, None, None, None, None, None, None, None, None], -1),
#  ([None, None, None, None, None, None, None, None, None, None], -1),
#  ([None], -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   -1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None,
#    None],
#   1),
#  ([None, None, None, None, None, None], 1)]

# %%
import math
